# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames[:3]:
#         print(os.path.join(dirname, filename))
#     if len(filenames) > 3:
#         print("...")

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import csv
import numpy as np
import random
import time

from tqdm import tqdm

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision.models import resnet18
from torchvision.io import read_image
import torchvision.transforms as transforms

# %%
TRAIN_PATH = "/kaggle/input/captcha-hacker/train"
#TEST_PATH = "/kaggle/input/captcha-hacker/test"
#TRAIN_PATH = "./train"
#TEST_PATH = "./test"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# try device = "cuda" 
# and change your settings/accelerator to GPU if you want it to run faster

# %%
code = {}
rev_code = {}

num = 0
for i in range(10):
    code[str(i)] = num
    rev_code[num] = str(i)
    num += 1

for i in range(ord('a'), ord('z') + 1):
    code[chr(i)]  = num
    rev_code[num] = chr(i)
    num += 1

#print(code)

# %%
def calc_acc(output, label):  
    digits = int(output.shape[1] / 36)
    output, label = output.view((-1, digits , 36)), label.view((-1, digits, 36))
    output = nn.functional.softmax(output, dim=2)
    
    output, label = torch.argmax(output, dim=2), torch.argmax(label, dim=2)
    
    correct = torch.sum(output == label, dim=1)
    correct = torch.sum(correct == digits, dim=0)

    return correct

# %%
train_data = []
val_data = []

with open(f'{TRAIN_PATH}/annotations.csv', newline='') as csvfile:
    for row in csv.reader(csvfile, delimiter=','):
        if random.random() < 0.8:
            train_data.append(row)
        else:
            val_data.append(row)

# %% [markdown]
# ## TASK1

# %%
class Task1Dataset(Dataset):
    def __init__(self, data, root, return_filename=False):
        self.data = [sample for sample in data if sample[0].startswith("task1")]
        self.return_filename = return_filename
        self.root = root
    
    def __getitem__(self, index):
        filename, label = self.data[index]
        img = read_image(f"{self.root}/{filename}")
        img = torch.as_tensor(img, dtype=torch.float32)
        
        transform = transforms.Compose([
            transforms.Resize(size=224),
            transforms.Normalize(mean=[0, 0, 0], std=[255, 255, 255]),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
        ])

        img = transform(img)
        if self.return_filename:
            return img, filename
        else:
            return img, int(label)

    def __len__(self):
        return len(self.data)

# %%
train_ds = Task1Dataset(train_data, root=TRAIN_PATH)
train_dl = DataLoader(train_ds, batch_size=100, num_workers=2, drop_last=True, shuffle=True)

val_ds = Task1Dataset(val_data, root=TRAIN_PATH)
val_dl = DataLoader(val_ds, batch_size=100, num_workers=2, drop_last=False, shuffle=False)

# %%
task1_model = resnet18(pretrained=True)
task1_model.fc = nn.Linear(in_features=512, out_features=10, bias=True)
task1_model = task1_model.to(device)
#print(model)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %%
optimizer = torch.optim.Adam(task1_model.parameters(), lr=1e-3)
loss_fn = nn.CrossEntropyLoss()


for epoch in range(15):
    print(f"Epoch [{epoch}]")
    task1_model.train()
    for image, label in train_dl:
        image = image.to(device)
        label = label.to(device)
        
        pred = task1_model(image)
        loss = loss_fn(pred, label)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        del image, label, pred
        #torch.cuda.empty_cache()
        
    sample_count = 0
    correct_count = 0
    task1_model.eval()
    with torch.no_grad():
        for image, label in val_dl:
            image = image.to(device)
            label = label.to(device)

            pred = task1_model(image)
            loss = loss_fn(pred, label)

            pred = torch.argmax(pred, dim=1)

            sample_count += len(image)
            correct_count += (label == pred).sum()

            del image, label, pred
            #torch.cuda.empty_cache()
        
    print("accuracy (validation):", correct_count / sample_count)

torch.save(task1_model.state_dict(), "task1_model.pt")
# Out:
# Epoch [0]
# accuracy (validation): tensor(0.6263, device='cuda:0')
# Epoch [1]
# accuracy (validation): tensor(0.9899, device='cuda:0')
# Epoch [2]
# accuracy (validation): tensor(0.9924, device='cuda:0')
# Epoch [3]
# accuracy (validation): tensor(1., device='cuda:0')
# Epoch [4]
# accuracy (validation): tensor(1., device='cuda:0')
# Epoch [5]
# accuracy (validation): tensor(1., device='cuda:0')
# Epoch [6]
# accuracy (validation): tensor(1., device='cuda:0')
# Epoch [7]
# accuracy (validation): tensor(1., device='cuda:0')
# Epoch [8]
# accuracy (validation): tensor(1., device='cuda:0')
# Epoch [9]
# accuracy (validation): tensor(1., device='cuda:0')
# Epoch [10]
# accuracy (validation): tensor(1., device='cuda:0')
# Epoch [11]
# accuracy (validation): tensor(1., device='cuda:0')
# Epoch [12]
# accuracy (validation): tensor(1., device='cuda:0')
# Epoch [13]
# accuracy (validation): tensor(1., device='cuda:0')
# Epoch [14]
# accuracy (validation): tensor(1., device='cuda:0')

# %% [markdown]
# ## TASK2

# %%
class Task2Dataset(Dataset):
    def __init__(self, data, root, return_filename=False):
        self.data = [sample for sample in data if sample[0].startswith("task2")]
        self.return_filename = return_filename
        self.root = root
    
    def __getitem__(self, index):
        filename, label = self.data[index]
        img = read_image(f"{self.root}/{filename}")
        img = torch.as_tensor(img, dtype=torch.float32)
        
        transform = transforms.Compose([
            transforms.Resize(size=224),
            transforms.Normalize(mean=[0, 0, 0], std=[255, 255, 255]),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
        ])

        img = transform(img)
        if self.return_filename:
            return img, filename
        else:
            #new_label = np.array([code[label[0]], code[label[1]]])
            #new_label = [0] * 72
            new_label = np.zeros(shape=72)
            new_label[code[label[0]]] = 1
            new_label[code[label[1]]+36] = 1
            #new_label += np.array([0, 36])
            new_label = torch.LongTensor(new_label)
            return img, new_label

    def __len__(self):
        return len(self.data)

# %%
train_ds = Task2Dataset(train_data, root=TRAIN_PATH)
train_dl = DataLoader(train_ds, batch_size=100, num_workers=2, drop_last=True, shuffle=True)

val_ds = Task2Dataset(val_data, root=TRAIN_PATH)
val_dl = DataLoader(val_ds, batch_size=100, num_workers=2, drop_last=False, shuffle=False)

# %%
task2_model = resnet18(pretrained=True)
task2_model.fc = nn.Linear(in_features=512, out_features=72, bias=True)
task2_model = task2_model.to(device)

# %%
optimizer = torch.optim.Adam(task2_model.parameters(), lr=1e-3)
loss_fn = nn.MultiLabelSoftMarginLoss()


for epoch in range(15):
    print(f"Epoch [{epoch}]")
    task2_model.train()

    train_loss = 0.0
    for image, label in train_dl:

        image = image.to(device)
        label = label.to(device)

        pred = task2_model(image)
        loss = loss_fn(pred, label)
        
        train_loss += loss
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        del image, label, pred
        #torch.cuda.empty_cache()
    
    train_loss /= len(train_dl)
    print("train loss: {}".format(train_loss))

    sample_count = 0
    correct_count = 0
    task2_model.eval()
    val_loss = 0
    
    with torch.no_grad():
        for image, label in val_dl:
            image = image.to(device)
            label = label.to(device)

            pred = task2_model(image)
            loss = loss_fn(pred, label)
            val_loss += loss

            sample_count += len(image)
            correct_count += calc_acc(pred, label)

            del image, label, pred
            #torch.cuda.empty_cache()

        val_loss /= len(val_dl)
        print("val loss: {}".format(val_loss))
        
    print("accuracy (validation):", correct_count / sample_count)

torch.save(task2_model.state_dict(), "task2_model.pt")
# Out:
# Epoch [0]
# train loss: 0.18872442841529846
# val loss: 0.11333496868610382
# accuracy (validation): tensor(0.0307, device='cuda:0')
# Epoch [1]
# train loss: 0.057765573263168335
# val loss: 0.03991683945059776
# accuracy (validation): tensor(0.8115, device='cuda:0')
# Epoch [2]
# train loss: 0.02292434498667717
# val loss: 0.019220542162656784
# accuracy (validation): tensor(0.9672, device='cuda:0')
# Epoch [3]
# train loss: 0.010974769480526447
# val loss: 0.010702262632548809
# accuracy (validation): tensor(0.9959, device='cuda:0')
# Epoch [4]
# train loss: 0.0065612331964075565
# val loss: 0.00845502968877554
# accuracy (validation): tensor(0.9980, device='cuda:0')
# Epoch [5]
# train loss: 0.004564496222883463
# val loss: 0.006629194598644972
# accuracy (validation): tensor(0.9939, device='cuda:0')
# Epoch [6]
# train loss: 0.0035351316910237074
# val loss: 0.00470530753955245
# accuracy (validation): tensor(0.9959, device='cuda:0')
# Epoch [7]
# train loss: 0.0029073588084429502
# val loss: 0.0038334287237375975
# accuracy (validation): tensor(0.9980, device='cuda:0')
# Epoch [8]
# train loss: 0.00244826334528625
# val loss: 0.0037093386054039
# accuracy (validation): tensor(0.9980, device='cuda:0')
# Epoch [9]
# train loss: 0.00211484357714653
# val loss: 0.0031079945620149374
# accuracy (validation): tensor(0.9980, device='cuda:0')
# Epoch [10]
# train loss: 0.001800704631023109
# val loss: 0.002569017233327031
# accuracy (validation): tensor(1.0000, device='cuda:0')
# Epoch [11]
# train loss: 0.0015580839244648814
# val loss: 0.0023549033794552088
# accuracy (validation): tensor(1.0000, device='cuda:0')
# Epoch [12]
# train loss: 0.0013751707738265395
# val loss: 0.0021377967204898596
# accuracy (validation): tensor(1.0000, device='cuda:0')
# Epoch [13]
# train loss: 0.001265836413949728
# val loss: 0.001981674926355481
# accuracy (validation): tensor(1.0000, device='cuda:0')
# Epoch [14]
# train loss: 0.001169330906122923
# val loss: 0.0017220225417986512
# accuracy (validation): tensor(1.0000, device='cuda:0')

# %% [markdown]
# ## TASK3

# %%
class Task3Dataset(Dataset):
    def __init__(self, data, root, return_filename=False):
        self.data = [sample for sample in data if sample[0].startswith("task3")]
        self.return_filename = return_filename
        self.root = root
    
    def __getitem__(self, index):
        filename, label = self.data[index]
        img = read_image(f"{self.root}/{filename}")
        img = torch.as_tensor(img, dtype=torch.float32)
        
        transform = transforms.Compose([
            transforms.Resize(size=(384, 288)),
            transforms.Normalize(mean=[0, 0, 0], std=[255, 255, 255]),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
        ])

        img = transform(img)
        if self.return_filename:
            return img, filename
        else:
            new_label = np.zeros(shape=144)
            for i in range(4):
                new_label[code[label[i]]+i*36] = 1
            new_label = torch.LongTensor(new_label)
            return img, new_label

    def __len__(self):
        return len(self.data)

# %%
train_ds = Task3Dataset(train_data, root=TRAIN_PATH)
train_dl = DataLoader(train_ds, batch_size=100, num_workers=2, drop_last=True, shuffle=True)

val_ds = Task3Dataset(val_data, root=TRAIN_PATH)
val_dl = DataLoader(val_ds, batch_size=100, num_workers=2, drop_last=False, shuffle=False)

# %%
task3_model = resnet18(pretrained=True)
task3_model.fc = nn.Linear(in_features=512, out_features=144, bias=True)
task3_model = task3_model.to(device)

# %%
optimizer = torch.optim.Adam(task3_model.parameters(), lr=1e-3)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=25, gamma=0.8)
loss_fn = nn.MultiLabelSoftMarginLoss()


for epoch in range(100):
    print(f"Epoch [{epoch}]")
    task3_model.train()

    train_loss = 0.0
    for image, label in train_dl:

        image = image.to(device)
        label = label.to(device)

        pred = task3_model(image)
        loss = loss_fn(pred, label)
        
        train_loss += loss
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        del image, label, pred
        #torch.cuda.empty_cache()
    
    scheduler.step()
    train_loss /= len(train_dl)
    print("train loss: {}".format(train_loss))

    sample_count = 0
    correct_count = 0
    task3_model.eval()
    val_loss = 0
    
    with torch.no_grad():
        for image, label in val_dl:
            image = image.to(device)
            label = label.to(device)

            pred = task3_model(image)
            loss = loss_fn(pred, label)
            val_loss += loss

            sample_count += len(image)
            correct_count += calc_acc(pred, label)

            del image, label, pred
            #torch.cuda.empty_cache()

        val_loss /= len(val_dl)
        print("val loss: {}".format(val_loss))
        
    print("accuracy (validation):", correct_count / sample_count)

torch.save(task3_model.state_dict(), "task3_model.pt")
# Out:
# Epoch [0]
# train loss: 0.19055402278900146
# val loss: 0.2002299427986145
# accuracy (validation): tensor(0., device='cuda:0')
# Epoch [1]
# train loss: 0.12125591933727264
# val loss: 0.12125589698553085
# accuracy (validation): tensor(0., device='cuda:0')
# Epoch [2]
# train loss: 0.1183542013168335
# val loss: 0.11833962798118591
# accuracy (validation): tensor(0., device='cuda:0')
# Epoch [3]
# train loss: 0.11407344788312912
# val loss: 0.11697398126125336
# accuracy (validation): tensor(0., device='cuda:0')
# Epoch [4]
# train loss: 0.10399691760540009
# val loss: 0.10403509438037872
# accuracy (validation): tensor(0., device='cuda:0')
# Epoch [5]
# train loss: 0.08697345852851868
# val loss: 0.08629818260669708
# accuracy (validation): tensor(0.0207, device='cuda:0')
# Epoch [6]
# train loss: 0.06647175550460815
# val loss: 0.06558462977409363
# accuracy (validation): tensor(0.1945, device='cuda:0')
# Epoch [7]
# train loss: 0.04788639396429062
# val loss: 0.04890618845820427
# accuracy (validation): tensor(0.4733, device='cuda:0')
# Epoch [8]
# train loss: 0.03282472491264343
# val loss: 0.040622226893901825
# accuracy (validation): tensor(0.6231, device='cuda:0')
# Epoch [9]
# train loss: 0.02288908138871193
# val loss: 0.030564313754439354
# accuracy (validation): tensor(0.7694, device='cuda:0')
# Epoch [10]
# train loss: 0.016143780201673508
# val loss: 0.023142315447330475
# accuracy (validation): tensor(0.8847, device='cuda:0')
# Epoch [11]
# train loss: 0.011762546375393867
# val loss: 0.019378848373889923
# accuracy (validation): tensor(0.9036, device='cuda:0')
# Epoch [12]
# train loss: 0.008947155438363552
# val loss: 0.016171690076589584
# accuracy (validation): tensor(0.9243, device='cuda:0')
# Epoch [13]
# train loss: 0.007099171634763479
# val loss: 0.014801563695073128
# accuracy (validation): tensor(0.9294, device='cuda:0')
# Epoch [14]
# train loss: 0.005760557949542999
# val loss: 0.013341809622943401
# accuracy (validation): tensor(0.9363, device='cuda:0')
# Epoch [15]
# train loss: 0.004786667414009571
# val loss: 0.010772492736577988
# accuracy (validation): tensor(0.9570, device='cuda:0')
# Epoch [16]
# train loss: 0.0038859739433974028
# val loss: 0.010185305029153824
# accuracy (validation): tensor(0.9639, device='cuda:0')
# Epoch [17]
# train loss: 0.0033593527041375637
# val loss: 0.010029807686805725
# accuracy (validation): tensor(0.9501, device='cuda:0')
# Epoch [18]
# train loss: 0.0028483406640589237
# val loss: 0.008636470884084702
# accuracy (validation): tensor(0.9690, device='cuda:0')
# Epoch [19]
# train loss: 0.0024080979637801647
# val loss: 0.008165702223777771
# accuracy (validation): tensor(0.9725, device='cuda:0')
# Epoch [20]
# train loss: 0.002116051036864519
# val loss: 0.007675876375287771
# accuracy (validation): tensor(0.9690, device='cuda:0')
# Epoch [21]
# train loss: 0.001898865681141615
# val loss: 0.007399104535579681
# accuracy (validation): tensor(0.9690, device='cuda:0')
# Epoch [22]
# train loss: 0.0016895224107429385
# val loss: 0.006997954100370407
# accuracy (validation): tensor(0.9673, device='cuda:0')
# Epoch [23]
# train loss: 0.0015781804686412215
# val loss: 0.007236971519887447
# accuracy (validation): tensor(0.9707, device='cuda:0')
# Epoch [24]
# train loss: 0.0014252301771193743
# val loss: 0.006555070169270039
# accuracy (validation): tensor(0.9742, device='cuda:0')
# Epoch [25]
# train loss: 0.0012366811279207468
# val loss: 0.006086395587772131
# accuracy (validation): tensor(0.9793, device='cuda:0')
# Epoch [26]
# train loss: 0.0010827460791915655
# val loss: 0.0058511849492788315
# accuracy (validation): tensor(0.9776, device='cuda:0')
# Epoch [27]
# train loss: 0.0010290067875757813
# val loss: 0.0059186602011322975
# accuracy (validation): tensor(0.9707, device='cuda:0')
# Epoch [28]
# train loss: 0.0009690959705039859
# val loss: 0.005717702209949493
# accuracy (validation): tensor(0.9759, device='cuda:0')
# Epoch [29]
# train loss: 0.0009001273429021239
# val loss: 0.0059356894344091415
# accuracy (validation): tensor(0.9690, device='cuda:0')
# Epoch [30]
# train loss: 0.0008485519210807979
# val loss: 0.005649399943649769
# accuracy (validation): tensor(0.9673, device='cuda:0')
# Epoch [31]
# train loss: 0.0008154407842084765
# val loss: 0.005245561711490154
# accuracy (validation): tensor(0.9725, device='cuda:0')
# Epoch [32]
# train loss: 0.0007552455645054579
# val loss: 0.005418637301772833
# accuracy (validation): tensor(0.9759, device='cuda:0')
# Epoch [33]
# train loss: 0.0007208266761153936
# val loss: 0.005298517644405365
# accuracy (validation): tensor(0.9742, device='cuda:0')
# Epoch [34]
# train loss: 0.0006997825112193823
# val loss: 0.005272991955280304
# accuracy (validation): tensor(0.9759, device='cuda:0')
# Epoch [35]
# train loss: 0.0006799273542128503
# val loss: 0.005168006755411625
# accuracy (validation): tensor(0.9742, device='cuda:0')
# Epoch [36]
# train loss: 0.0006122662452980876
# val loss: 0.0051736291497945786
# accuracy (validation): tensor(0.9707, device='cuda:0')
# Epoch [37]
# train loss: 0.0005775907193310559
# val loss: 0.00501204002648592
# accuracy (validation): tensor(0.9759, device='cuda:0')
# Epoch [38]
# train loss: 0.0005517489626072347
# val loss: 0.004854350816458464
# accuracy (validation): tensor(0.9776, device='cuda:0')
# Epoch [39]
# train loss: 0.0005362310912460089
# val loss: 0.004893549717962742
# accuracy (validation): tensor(0.9742, device='cuda:0')
# Epoch [40]
# train loss: 0.0005128154880367219
# val loss: 0.004853895399719477
# accuracy (validation): tensor(0.9811, device='cuda:0')
# Epoch [41]
# train loss: 0.0004837967862840742
# val loss: 0.004686244297772646
# accuracy (validation): tensor(0.9793, device='cuda:0')
# Epoch [42]
# train loss: 0.0004602978879120201
# val loss: 0.00502088014036417
# accuracy (validation): tensor(0.9776, device='cuda:0')
# Epoch [43]
# train loss: 0.00045277568278834224
# val loss: 0.004769577644765377
# accuracy (validation): tensor(0.9776, device='cuda:0')
# Epoch [44]
# train loss: 0.00043250256567262113
# val loss: 0.004653152544051409
# accuracy (validation): tensor(0.9776, device='cuda:0')
# Epoch [45]
# train loss: 0.00041723574395291507
# val loss: 0.0046385410241782665
# accuracy (validation): tensor(0.9811, device='cuda:0')
# Epoch [46]
# train loss: 0.00039519823621958494
# val loss: 0.004577408544719219
# accuracy (validation): tensor(0.9828, device='cuda:0')
# Epoch [47]
# train loss: 0.00037476152647286654
# val loss: 0.004380486439913511
# accuracy (validation): tensor(0.9811, device='cuda:0')
# Epoch [48]
# train loss: 0.0003572017594706267
# val loss: 0.00447308924049139
# accuracy (validation): tensor(0.9742, device='cuda:0')
# Epoch [49]
# train loss: 0.00035218262928538024
# val loss: 0.0046004666946828365
# accuracy (validation): tensor(0.9793, device='cuda:0')
# Epoch [50]
# train loss: 0.0003406430478207767
# val loss: 0.004577293526381254
# accuracy (validation): tensor(0.9811, device='cuda:0')
# Epoch [51]
# train loss: 0.0003206384717486799
# val loss: 0.004323901608586311
# accuracy (validation): tensor(0.9793, device='cuda:0')
# Epoch [52]
# train loss: 0.0003117320011369884
# val loss: 0.004290930926799774
# accuracy (validation): tensor(0.9811, device='cuda:0')
# Epoch [53]
# train loss: 0.0003091456601396203
# val loss: 0.004318502731621265
# accuracy (validation): tensor(0.9828, device='cuda:0')
# Epoch [54]
# train loss: 0.00029917998472228646
# val loss: 0.004515836015343666
# accuracy (validation): tensor(0.9776, device='cuda:0')
# Epoch [55]
# train loss: 0.00029055081540718675
# val loss: 0.004196497146040201
# accuracy (validation): tensor(0.9811, device='cuda:0')
# Epoch [56]
# train loss: 0.0002771901781670749
# val loss: 0.0042367130517959595
# accuracy (validation): tensor(0.9862, device='cuda:0')
# Epoch [57]
# train loss: 0.00026284801424480975
# val loss: 0.00418013334274292
# accuracy (validation): tensor(0.9828, device='cuda:0')
# Epoch [58]
# train loss: 0.00025258641107939184
# val loss: 0.004129473119974136
# accuracy (validation): tensor(0.9811, device='cuda:0')
# Epoch [59]
# train loss: 0.00025129917776212096
# val loss: 0.0041483864188194275
# accuracy (validation): tensor(0.9759, device='cuda:0')
# Epoch [60]
# train loss: 0.00025009794626384974
# val loss: 0.00424195546656847
# accuracy (validation): tensor(0.9811, device='cuda:0')
# Epoch [61]
# train loss: 0.00024201702035497874
# val loss: 0.004077507182955742
# accuracy (validation): tensor(0.9811, device='cuda:0')
# Epoch [62]
# train loss: 0.00023770965344738215
# val loss: 0.004026241134852171
# accuracy (validation): tensor(0.9759, device='cuda:0')
# Epoch [63]
# train loss: 0.00022703566355630755
# val loss: 0.004081851337105036
# accuracy (validation): tensor(0.9793, device='cuda:0')
# Epoch [64]
# train loss: 0.00021625454246532172
# val loss: 0.0040196580812335014
# accuracy (validation): tensor(0.9811, device='cuda:0')
# Epoch [65]
# train loss: 0.0002190833183703944
# val loss: 0.004092891700565815
# accuracy (validation): tensor(0.9828, device='cuda:0')
# Epoch [66]
# train loss: 0.00021175548317842185
# val loss: 0.004003878682851791
# accuracy (validation): tensor(0.9793, device='cuda:0')
# Epoch [67]
# train loss: 0.0002022106054937467
# val loss: 0.003971877507865429
# accuracy (validation): tensor(0.9725, device='cuda:0')
# Epoch [68]
# train loss: 0.00019485107623040676
# val loss: 0.00398548599332571
# accuracy (validation): tensor(0.9811, device='cuda:0')
# Epoch [69]
# train loss: 0.00019341736333444715
# val loss: 0.00406213803216815
# accuracy (validation): tensor(0.9793, device='cuda:0')
# Epoch [70]
# train loss: 0.00019016722217202187
# val loss: 0.004053897690027952
# accuracy (validation): tensor(0.9793, device='cuda:0')
# Epoch [71]
# train loss: 0.00018675489991437644
# val loss: 0.0041695404797792435
# accuracy (validation): tensor(0.9828, device='cuda:0')
# Epoch [72]
# train loss: 0.00015735748456791043
# val loss: 0.0038397915195673704
# accuracy (validation): tensor(0.9776, device='cuda:0')
# Epoch [78]
# train loss: 0.00015613668074365705
# val loss: 0.003859167452901602
# accuracy (validation): tensor(0.9811, device='cuda:0')
# Epoch [79]
# train loss: 0.00014951542834751308
# val loss: 0.0038617788814008236
# accuracy (validation): tensor(0.9811, device='cuda:0')
# Epoch [80]
# train loss: 0.00014609807112719864
# val loss: 0.003909624647349119
# accuracy (validation): tensor(0.9776, device='cuda:0')
# Epoch [81]
# train loss: 0.0001429266412742436
# val loss: 0.0038029176648706198
# accuracy (validation): tensor(0.9811, device='cuda:0')
# Epoch [82]
# train loss: 0.0001400397450197488
# val loss: 0.0037893119733780622
# accuracy (validation): tensor(0.9793, device='cuda:0')
# Epoch [83]
# train loss: 0.00013518150080926716
# val loss: 0.0037966901436448097
# accuracy (validation): tensor(0.9828, device='cuda:0')
# Epoch [84]
# train loss: 0.00013418130401987582
# val loss: 0.0037699181120842695
# accuracy (validation): tensor(0.9793, device='cuda:0')
# Epoch [85]
# train loss: 0.00013249700714368373
# val loss: 0.003813746152445674
# accuracy (validation): tensor(0.9793, device='cuda:0')
# Epoch [86]
# train loss: 0.0001297332055401057
# val loss: 0.00380686460994184
# accuracy (validation): tensor(0.9828, device='cuda:0')
# Epoch [87]
# train loss: 0.000132018729345873
# val loss: 0.003746812930330634
# accuracy (validation): tensor(0.9828, device='cuda:0')
# Epoch [88]
# train loss: 0.00013152751489542425
# val loss: 0.0038233515806496143
# accuracy (validation): tensor(0.9828, device='cuda:0')
# Epoch [89]
# train loss: 0.00012799451360478997
# val loss: 0.0036971389781683683
# accuracy (validation): tensor(0.9793, device='cuda:0')
# Epoch [90]
# train loss: 0.00012113020056858659
# val loss: 0.003819466568529606
# accuracy (validation): tensor(0.9793, device='cuda:0')
# Epoch [91]
# train loss: 0.00011844473192468286
# val loss: 0.003768298542127013
# accuracy (validation): tensor(0.9811, device='cuda:0')
# Epoch [92]
# train loss: 0.0001184439315693453
# val loss: 0.0038025060202926397
# accuracy (validation): tensor(0.9793, device='cuda:0')
# Epoch [93]
# train loss: 0.00011641616583801806
# val loss: 0.0037915853317826986
# accuracy (validation): tensor(0.9793, device='cuda:0')
# Epoch [94]
# train loss: 0.00011515953519847244
# val loss: 0.003778437152504921
# accuracy (validation): tensor(0.9793, device='cuda:0')
# Epoch [95]
# train loss: 0.00011377684859326109
# val loss: 0.0038719940930604935
# accuracy (validation): tensor(0.9811, device='cuda:0')
# Epoch [96]
# train loss: 0.00011037437070626765
# val loss: 0.0037928204983472824
# accuracy (validation): tensor(0.9793, device='cuda:0')
# Epoch [97]
# train loss: 0.00010853472485905513
# val loss: 0.0036851027980446815
# accuracy (validation): tensor(0.9811, device='cuda:0')
# Epoch [98]
# train loss: 0.00010497681068954989
# val loss: 0.003573015332221985
# accuracy (validation): tensor(0.9811, device='cuda:0')
# Epoch [99]
# train loss: 0.00010555323387961835
# val loss: 0.0037050913088023663
# accuracy (validation): tensor(0.9828, device='cuda:0')
